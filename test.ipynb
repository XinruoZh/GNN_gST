# %%
import sys
import cell2location
import torch_geometric

print(f"Python Version: {sys.version}") # Should be 3.10.x
print(f"Cell2Loc Path: {cell2location.__file__}") # Should be your /ocean/... path
print("Installation Successful!")
# Out:
# Python Version: 3.10.19 | packaged by conda-forge | (main, Oct 22 2025, 22:29:10) [GCC 14.3.0]
# Cell2Loc Path: None
# Installation Successful!
